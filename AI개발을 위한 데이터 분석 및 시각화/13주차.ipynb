# %% [markdown]
# # 13주차 2강 실습

# %% [markdown]
# ## < 텍스트 마이닝 >
# - 비정형 데이터, 텍스트 데이터로부터 유의미한 정보를 추출하는 데이터 분석을 텍스트 마이닝(Text Mining)이라고 한다.

# %% [markdown]
# ### 1. 웹 크롤링으로 기초 데이터 수집
# - 대상 페이지의 구조 살펴보기
# - www.namu.wiki
# - 웹 크롤링 라이브러리 사용하기

# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install selenium beautifulsoup4
# Out:
# Requirement already satisfied: selenium in c:\users\user\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: urllib3 in c:\users\user\anaconda3\lib\site-packages (from selenium) (1.25.8)

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (4.5.0)

# %%
from selenium import webdriver
import requests # 크롤링을 해주는 라이브러리
from bs4 import BeautifulSoup
import re

# 윈도우용 크롬 웹드라이버 실행 경로 (Windows)
excutable_path = "./chapter4/chromedriver.exe"

# %%
# 크롤링할 사이트 주소를 정의한다.
source_url = "https://namu.wiki/RecentChanges"

# 크롬 드라이버를 사용합니다.
driver = webdriver.Chrome(executable_path=excutable_path)

# 드라이버가 브라우징 할 페이지 소스를 입력합니다
driver.get(source_url)
req = driver.page_source
# req = requests.get(source_url)
# html = req.content

# %%
# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
soup = BeautifulSoup(req, "html.parser")
contents_table = soup.find(name = 'table')
table_body = contents_table.find(name = 'tbody')
table_rows = table_body.find_all(name = 'tr')
# soup
# contents_table

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성한다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거한다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
    
# 크롤링에 사용한 브라우저를 종료합니다.
driver.close()
# Out:
# https://namu.wiki/w/(%EC%97%AC%EC%9E%90)%EC%95%84%EC%9D%B4%EB%93%A4/%EC%9D%8C%EB%B0%98%20%EB%AA%A9%EB%A1%9D
# https://namu.wiki/w/%EC%A7%84%EC%A3%BC%20%EB%B2%84%EC%8A%A4%20130
# https://namu.wiki/w/%ED%95%B4%EC%9A%B4%EB%8C%80%20%EC%97%B0%EC%9D%B8%EB%93%A4
# https://namu.wiki/w/%EC%9A%94%EA%B4%B4%EB%8C%80%EC%A0%84
# https://namu.wiki/w/%EC%9E%A5%EB%8B%A4%EC%9A%B4

# %% [markdown]
# - 위의 코드를 통해 https://namu.wiki/RecentChanges 페이지의 최근 변경 문서 링크들을 추출.

# %% [markdown]
# ### [ 텍스트 정보 수집하기 ]

# %%
# 크롬 드라이버를 사용합니다
driver = webdriver.Chrome(executable_path=excutable_path)

# 드라이버가 브라우징 할 페이지 소스를 입력합니다
# req = requests.get(page_urls[0])
# html = req.content
# soup = BeautifulSoup(html, 'lxml')
driver.get(page_urls[0])
req = driver.page_source
soup = BeautifulSoup(req, "html.parser")
contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
을 참고하십시오.<I burn> TRACK LIST 트랙곡명작사작곡편곡01한(寒)소연, 안예은BreadBeat, 안예은, 소연02화(火花)소연소연, Pop Time03MOON소연민니, FCM 후디니, FCM 667FCM 후디니, 민니04Where is love소연, 이우민, "collapsedone"이우민, "collapsedone"05LOST우기, 서재우, 소연서재우, 우기서재우06DAHLIABreadBeat, 민니, 소연BreadBeat, 민니BreadBeat   자세한 내용은 I burn 문서를의 번 문단을의  부분을 참고하십시오.<DUMDi DUMDi> TRACK LIST 트랙곡명작사작곡편곡01DUMDi DUMDi소연소연, Pop TimePop Time, 소연   자세한 내용은 DUMDi DUMDi 문서를의 번 문단을의  부분을 참고하십시오.<한(一)> TRACK LIST 트랙곡명작사작곡편곡01한(一)전소연전소연, 빅싼초   자세한 내용은 한(一) 문서를의 번 문단을의  부분을 참고하십시오.<Uh-Oh> TRACK LIST 트랙곡명작사작곡편곡01Uh-O ...

# %% [markdown]
# ### [ 나무위키 최근변경 데이터 크롤링 ]

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비합니다.
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns = columns)

# 각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만듭니다.
for page_url in page_urls:
    
    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    driver = webdriver.Chrome(executable_path=excutable_path)
    # req = requests.get(page_url)
    # html = req.content
    driver.get(page_url)
    req = driver.page_source
    soup = BeautifulSoup(req, "html.parser")
    contents_table = soup.find(name = 'article')
    title = contents_table.find_all('h1')[0]
    
    # 카테고리 정보가 없는 경우를 확인합니다.
    if len(contents_table.find_all('ul')) > 0:
        category = contents_table.find_all('ul')[0]
    else:
        category = None
        
    content_paragraphs = contents_table.find_all(name = 'div', attrs = {"class":"wiki-paragraph"})
    content_corpus_list = []
    
    # 페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ")
    else:
        row_title = ""
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.    
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
     
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
        
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.    
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index = df.columns)
    df = df.append(series, ignore_index = True)
    
    # 크롤링에 사용한 브라우저를 종료합니다.
    driver.close()

# %%
# 데이터 프레임을 출력합니다.
df.head(5)
# Out:
#             title                                           category  \
# 0  (여자)아이들/음반 목록                (여자)아이들아티스트별 음반 목록한국의 음반일본의 음반미국의 음반
# 1      진주 버스 130                             진주시 시내버스1965년 개업한 버스 노선
# 2        해운대 연인들              KBS 드라마월화 드라마2012년 드라마부산광역시를 배경으로 한 작품
# 3           요괴대전                        네이버 웹툰소년 만화다크 판타지 만화2019년 웹툰
# 4            장다운   유튜버/ㅈ한국 여성 코미디언/ㅈ1988년 출생2013년 데뷔흔한남매백제예술대학교 출...
#
#                                         content_text
# 0     상위 문서: (여자)아이들  미연민니수진소연우기슈화 [ 한국 음반 ] I am...
# 1   진주시 시내버스 [ 펼치기 · 접기 ]통학 노선1020동부 순환001002002-...
# 2    월화 드라마  [ 펼치기 · 접기 ]2011~2015드림 하이(2011)강력반(...
# 3   네이버 웹툰의 연재작월화수목금토일요괴대전장르액션, 판타지[1]작가글: 강두식그림:...
# 4  장다운Jang Da-Wun출생1988년 7월 9일 (33세)출생지광주광역시[1]거주...

# %% [markdown]
# ### 2. 추출 : 키워드 추출
# #### [ 텍스트 데이터 전처리 ]

# %%
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타낸다
    result = hangul.sub('', text)
    return result

print(text_cleaning(df['content_text'][0]))
# Out:
#   상위 문서 여자아이들  미연민니수진소연우기슈화  한국 음반   미니 집  한디싱 집  미니 집  디싱 집   미니 집    디싱 집    싱글 집    미니 집   화디싱 집   해외 음반 일본 음반미니 집   미니 집 미국 음반  디싱    참여 음반 달려  컴백전쟁 퀸덤 컴백 싱글      관련 문서 음반 목록응원법네버랜드  컴백전쟁 퀸덤네버엔딩 네버랜드논란 및 사건 사고   미연민니수진소연우기슈화  한국 음반   미니 집  한디싱 집  미니 집  디싱 집   미니 집    디싱 집    싱글 집    미니 집   화디싱 집   해외 음반 일본 음반미니 집   미니 집 미국 음반  디싱    참여 음반 달려  컴백전쟁 퀸덤 컴백 싱글      관련 문서 음반 목록응원법네버랜드  컴백전쟁 퀸덤네버엔딩 네버랜드논란 및 사건 사고  미니 집  한디싱 집  미니 집  디싱 집   미니 집    디싱 집    싱글 집    미니 집   화디싱 집 일본 음반미니 집   미니 집 미국 음반  디싱 달려  컴백전쟁 퀸덤 컴백 싱글    음반 목록응원법네버랜드  컴백전쟁 퀸덤네버엔딩 네버랜드논란 및 사건 사고 개요 한국 음반 미니 앨범 미니 집   미니 집   미니 집   미니 집   싱글 싱글 집   디지털 싱글 디지털 싱글 한 디지털 싱글  디지털 싱글    일본 음반 미니 집  미니 집    미국 음반 디지털 싱글    가사 참여 음반   런닝맨 풀룰루의 역습  그녀의 사생활    컴백전쟁 퀸덤    대한민국의 걸그룹 여자아이들의 음반 목록을 정리해둔 문서이다발매일앨범 아트음반 종류음반명활동 곡비고년월 일미니 집 월 일디지털 싱글한한년월 일미니 집 월 일디지털 싱글년월 일미니 집   사랑해월 일디지털 싱글  월 일싱글 집  년월 일미니 집 화    트랙곡명작사작곡편곡전소연전소연 빅싼초달라  전소연윤종성 윤종성손영진  전소연손영진   빅싼초 박해일재리포터 전소연빅싼초 박해일재리포터빅싼초 박해일알고 싶어    전소연    들어줘요손영진 노경민손영진가온 차트를 기준으로 주간  에 차트인 했으며 월간 차트에서는 월에 위로 월간차트에 진입 했으며 월에 위로 최고 순위를 기록하고 월에 위 월에 위 월에 위를 기록한다 연간차트에서는 위를 기록했다  자세한 내용은  여자아이들 문서를의 번 문단을의  부분을 참고하십시오    트랙곡명작사작곡편곡전소연전소연 빅싼초빅싼초 전소연  전소연전소연이우민 이우민 싫다고 말해전소연후디니 전소연주세요전소연전소연 후디니후디니 전소연  민니   전소연민니    민니  자세한 내용은   문서를의 번 문단을의  부분을 참고하십시오    트랙곡명작사작곡편곡  전소연전소연 빅싼초빅싼초 전소연사랑해전소연전소연 빅싼초빅싼초 전소연전소연전소연이우민 이우민 전소연전소연 빅싼초빅싼초 전소연    전소연  전소연 빅싼초빅싼초 전소연  자세한 내용은   문서를의 번 문단을의  부분을 참고하십시오    트랙곡명작사작곡편곡한소연 안예은 안예은 소연화소연소연  소연민니  후디니   후디니 민니  소연 이우민 이우민 우기 서재우 소연서재우 우기서재우 민니 소연 민니  자세한 내용은   문서를의 번 문단을의  부분을 참고하십시오    트랙곡명작사작곡편곡 소연소연    소연  자세한 내용은   문서를의 번 문단을의  부분을 참고하십시오한   트랙곡명작사작곡편곡한전소연전소연 빅싼초  자세한 내용은 한 문서를의 번 문단을의  부분을 참고하십시오   트랙곡명작사작곡편곡전소연전소연 쥰 쥰   자세한 내용은 여자아이들 문서를의 번 문단을의  부분을 참고하십시오     트랙곡명작사작곡편곡  민니 우기 소연 후디니민니 우기 유토 후디니후디니 유토  자세한 내용은    문서를의 번 문단을의  부분을 참고하십시오발매일앨범 아트음반 종류음반명활동 곡비고년월 일미니 집  년월 일미니 집       발매일앨범 아트음반 종류음반명활동 곡비고년월 일디지털 싱글    글로벌 히트곡    발매북미시장 진출에 이어 글로벌 그룹으로 자리매김하기 위한 여자아이들의 도약많은 찬사를 받았던 세 번째 미니앨범   타이틀곡   에 이어서 큰 사랑을 받았던 여자아이들의 데뷔곡 의 영어 버전이 발매되었다 이미 케이팝 센세이션 트렌드세터 등의 호평을 받고 있는 여자아이들이 앞으로 글로벌 시장에서 어떤 활약을 보여줄지 더욱 기대하게 만드는   은 듣자마자 단번에 알아차릴 수 있는 익숙하고 신나는 멜로디에 영어 가사를 얹어 매력이 한 층 더 깊어졌다 스타일리시한 리릭비디오도 함께 선보여 글로벌 시장을 향한 적극적인 발돋움을 보여준다매 앨범마다 색다른 모습을 추구하며 다양한 매력을 선사한 여자아이들은 지난 월 세 번째 미니앨범  를 발매함과 동시에 미국의 리퍼블릭 레코드와 파트너십을 맺고 미국 진출을 본격화함을 알렸다 셀프 프로듀싱을 하며 당당하게 자신들만의 음악을 만들어가고 있는 여자아이들의 새로운 도약이 기대되며 글로벌 영향력과 포텐셜을 보여주려 하는 올 년은 여자아이들의 가장 크고 대담한 해가 될 것으로 예상된다        미연 민니 수진 소연 우기 슈화                                                                                                                                                                                                                                                                                                                                                     트랙 곡명 작사 작곡 편곡  정일훈정일훈      이민혁 프니엘 정일훈 장예은 우석 소연빅싼초 박해일한걸음손영진 임현식손영진  서재우 서용재  현아 이민혁 프니엘 장예은 권은빈 이던 유토 우석 소연서재우 서용재 년 월 일 발매트랙 곡명 작사 작곡 편곡 라이엇 게임즈라이엇 게임즈 라이엇 게임즈   년 월 일 발매리그 오브 레전드 팝스타 스킨 시리즈의 일환으로  스킨이 발매되면서 함께 공개된 걸그룹 의 노래로 미연 소연이    와 함께 참여하였다 소연은 아칼리 미연은 아리의 부분을 맡아서 불렀으며 리그 오브 레전드  월드 챔피언십 결승전 오프닝 무대에 올라 무대를 직접 선보였다트랙 곡명 작사 작곡 편곡 달려  애니메이션 런닝맨 시즌 엔딩곡       라인프렌즈        달려  달려    년 월 일 발매년 월 일에 개봉한 애니메이션 런닝맨 풀룰루의 역습의 엔딩곡이다트랙 곡명 작사 작곡 편곡  박근철 임현준 전소연박근철 임현준박근철 임현준 유웅열 박근철 임현준박근철 임현준 유웅열    게시 하루만에 유튜브 조회수 만을 넘었다년 월 일 발매여자아이들 데뷔 후 첫 드라마 이다  자세한 내용은 여자아이들컴백전쟁 퀸덤 문서를의 번 문단을의  부분을 참고하십시오  트랙  제목   작사   작곡   편곡   라이엇 뮤직 팀  라이엇 뮤직 팀  라이엇 뮤직 팀 트랙  제목   작사   작곡   편곡  라이엇 뮤직 팀  라이엇 뮤직 팀  라이엇 뮤직 팀              트랙 곡명 작사 작곡 편곡   소연 소연년 월 일 발매에서 발매하는 번째 디지털 싱글에 여자아이들이 참여하였다  자세한 내용은  여자아이들 문서를의 번 문단을의  부분을 참고하십시오 데뷔 앨범 활동은 하지 않는다 커버 아트가  일본음반 초회한정판 와 동일하다 이 문서의 내용 중 전체 또는 일부는 여자아이들 문서의  판 번 문단에서 가져왔습니다 이전 역사 보러 가기 이 문서의 내용 중 전체 또는 일부는 다른 문서에서 가져왔습니다  펼치기  접기 여자아이들 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문단 이전 역사 문서의  판 번 문 ...

# %%
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#          title                                           category  \
# 0  여자아이들음반 목록                  여자아이들아티스트별 음반 목록한국의 음반일본의 음반미국의 음반
# 1      진주 버스                                  진주시 시내버스년 개업한 버스 노선
# 2     해운대 연인들                      드라마월화 드라마년 드라마부산광역시를 배경으로 한 작품
# 3        요괴대전                            네이버 웹툰소년 만화다크 판타지 만화년 웹툰
# 4         장다운   유튜버ㅈ한국 여성 코미디언ㅈ년 출생년 데뷔흔한남매백제예술대학교 출신코미디언 출신 유...
#
#                                         content_text
# 0    상위 문서 여자아이들  미연민니수진소연우기슈화  한국 음반   미니 집  한디싱...
# 1   진주시 시내버스  펼치기  접기 통학 노선동부 순환경상대권역진양호권역이현동권역서부...
# 2    월화 드라마   펼치기  접기 드림 하이강력반동안미녀스파이 명월포세이돈브레인드림...
# 3   네이버 웹툰의 연재작월화수목금토일요괴대전장르액션 판타지작가글 강두식그림 장부규연재...
# 4  장다운 출생년 월 일 세출생지광주광역시거주지인천광역시 서구 불로동신체  형  발사이...

# %% [markdown]
# #### [ 말뭉치 만들기 ]

# %%
title_corpus = "".join(df['title'].tolist())
category_corpus = "".join(df['category'].tolist())
content_corpus = "".join(df['content_text'].tolist())
print(title_corpus)
# Out:
# 여자아이들음반 목록 진주 버스  해운대 연인들 요괴대전 장다운 동신중학교서울 김영주북한 근첩     주차 레킹볼 파일원작 버려진 전생현자 마물의 숲에서 최강의 대마제국을 일구어낸다 마요왕군게임국 성폭행 명예훼손 사건 파일 블래스터 마스터 제로 시리즈등장 캐릭터 찬이 패션 모델 정환 색각 이상 의성군 근육맨 세  신한은행   카트라이더 리그 시즌팀전강 클로저스시스템 순당무 월 일 폴 부아예 분류 파리 올림픽 메달리스트 삼성 라이온즈년월 년 정치 혐오 라무링 연휴 아야이터널 리턴 잭 니클라우스 별난 이름 행정구역 개편수도권인천개편론 공격형 미드필더 선바 미니 갤러리의 사생활 폭로 논란 영등포고등학교 창씨개명  오베론 시리즈 틀레드벨벳아이린슬기 진주 버스  연기돌 검정고시 나카무라 유이치 백수 해적단 동이드라마 예천군 고래사냥영화 커트 코베인 몽타주 오브 헥 우사다 레터스 건빵 마음의소리등장인물 모여봐요 동물의 숲마일 여행권 신인호 키미즈카 키미히코 마가렛 아이브 애보트   루트 밀림 나바 공녀님의 꽃밭에는 그들이 산다 이우진 김황록  논란 및 문제점 틀세기 이후 철학 언론의 메갈리아 워마드 옹호 퓰리처상  리그역사 왓 이프

# %%
test_list = ['aa', 'bb', 'cc']
','.join(test_list)
# Out:
# 'aa,bb,cc'

# %% [markdown]
# # 13주차 3강 실습

# %% [markdown]
# ### 1. konlpy를 이용하여 키워드 추출하기
# - 코드 실행을 위해 아나콘다 프롬프터에 설치한다
# - 명령어 : pip install konlpy, pip install jpype1, pip install jpype1-py3

# %% [markdown]
# ### [ 키워드 가다듬기 ]
# - 한글자 키워드 제거

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\user\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: JPype1>=0.5.7 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (1.3.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\users\user\anaconda3\lib\site-packages (from JPype1>=0.5.7->konlpy) (3.7.4.3)

# %%
# !pip install konlpy==0.5.1
# !pip install jpype1
# !pip install Jpype1-py3
# Out:
# Requirement already satisfied: konlpy==0.5.1 in c:\users\user\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: JPype1>=0.5.7 in c:\users\user\anaconda3\lib\site-packages (from konlpy==0.5.1) (1.3.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\users\user\anaconda3\lib\site-packages (from JPype1>=0.5.7->konlpy==0.5.1) (3.7.4.3)
# Requirement already satisfied: jpype1 in c:\users\user\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\users\user\anaconda3\lib\site-packages (from jpype1) (3.7.4.3)
# Requirement already satisfied: Jpype1-py3 in c:\users\user\anaconda3\lib\site-packages (0.5.5.4)

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(content_corpus)
count = Counter(nouns)

# %%
count
# Out:
# Counter({'상위': 62,
#          '문서': 1421,
#          '여자아이': 26,
#          '미연': 6,
#          '민니': 10,
#          '수진': 3,
#          '연우': 10,
#          '기슈': 2,
#          '한국': 357,
#          '음반': 36,
#          '미니': 57,
#          '집': 119,
#          '한디싱': 3,
#          '디싱': 9,
#          '싱글': 22,
#          '화디싱': 3,
#          '해외': 66,
#          '일본': 351,
#          '미국': 170,
#          '참여': 65,
#          '컴백': 18,
#          '전쟁': 46,
#          '퀸덤': 8,
#          '관련': 260,
#          '목록': 72,
#          '응원': 20,
#          '법': 68,
#          '네버랜드': 6,
#          '네버엔딩': 3,
#          '논란': 154,
#          '및': 260,
#          '사건': 270,
#          '사고': 63,
#          '개요': 57,
#          '앨범': 12,
#          '디지털': 17,
#          '가사': 6,
#          '런닝맨': 7,
#          '풀': 52,
#          '룰루': 18,
#          '역습': 4,
#          '그녀': 86,
#          '사생활': 9,
#          '대한민국': 186,
#          '걸그룹': 46,
#          '정리': 52,
#          '다발': 4,
#          '매일': 20,
#          '아트': 7,
#          '종류': 82,
#          '활동': 151,
#          '곡': 46,
#          '비고': 11,
#          '년월': 49,
#          '일미': 16,
#          '월': 1329,
#          '사랑': 62,
#          '화': 241,
#          '트랙': 939,
#          '곡명': 13,
#          '작곡': 17,
#          '편곡': 17,
#          '소연': 38,
#          '빅싼초달': 1,
#          '윤': 11,
#          '종성': 2,
#          '손영진': 6,
#          '빅싼초': 2,
#          '박해일': 4,
#          '재': 79,
#          '리포터': 3,
#          '빅': 36,
#          '초': 241,
#          '빅싼': 1,
#          '알': 182,
#          '노': 74,
#          '경민': 1,
#          '가온': 4,
#          '차트': 24,
#          '기준': 145,
#          '주간': 17,
#          '월간': 12,
#          '위로': 42,
#          '진입': 51,
#          '최고': 79,
#          '순위': 86,
#          '기록': 131,
#          '위': 469,
#          '연간': 7,
#          '내용': 300,
#          '를': 405,
#          '번': 1618,
#          '문단': 1411,
#          '의': 737,
#          '부분': 387,
#          '참고': 186,
#          '빅싼초빅싼초': 5,
#          '우민': 6,
#          '말': 518,
#          '후디니': 8,
#          '연민': 2,
#          '작사': 11,
#          '해전': 6,
#          '연전': 11,
#          '한소연': 1,
#          '안예은': 2,
#          '우기': 8,
#          '서재우': 5,
#          '쥰': 4,
#          '유토': 3,
#          '오발': 1,
#          '발매': 66,
#          '글로벌': 12,
#          '히트': 29,
#          '북미': 23,
#          '시장': 44,
#          '진출': 71,
#          '그룹': 134,
#          '도약': 6,
#          '찬사': 4,
#          '세': 166,
#          '미니앨범': 2,
#          '타이틀곡': 2,
#          '데뷔': 51,
#          '영어': 38,
#          '버전': 23,
#          '케이팝': 3,
#          '센세이션': 10,
#          '트렌드': 6,
#          '세터': 1,
#          '등': 910,
#          '호평': 11,
#          '앞': 115,
#          '활약': 54,
#          '더욱': 67,
#          '은': 107,
#          '단번': 4,
#          '수': 1385,
#          '멜로디': 3,
#          '매력': 7,
#          '층': 67,
#          '더': 492,
#          '스타일리시': 1,
#          '리릭': 1,
#          '비디오': 15,
#          '향': 66,
#          '적극': 24,
#          '발돋움': 2,
#          '모습': 274,
#          '추구': 21,
#          '선사': 2,
#          '지난': 31,
#          '함': 62,
#          '동시': 67,
#          '리퍼블릭': 1,
#          '레코드': 1,
#          '파트너': 18,
#          '본격': 39,
#          '셀프': 4,
#          '프로듀싱': 1,
#          '자신': 368,
#          '음악': 45,
#          '며': 23,
#          '영향력': 21,
#          '포텐셜': 2,
#          '년': 1251,
#          '가장': 194,
#          '해': 132,
#          '것': 1908,
#          '예상': 28,
#          '슈화': 1,
#          '정일훈': 3,
#          '이민혁': 3,
#          '프니엘': 2,
#          '장': 57,
#          '예은': 2,
#          '우석': 2,
#          '걸음': 4,
#          '임현식': 1,
#          '현아': 3,
#          '권': 47,
#          '은빈': 1,
#          '일': 1031,
#          '라이엇': 11,
#          '게임': 272,
#          '리그': 177,
#          '오브': 99,
#          '레전드': 55,
#          '팝스타': 1,
#          '스킨': 6,
#          '시리즈': 121,
#          '일환': 9,
#          '공개': 96,
#          '노래': 37,
#          '아칼리': 1,
#          '아리': 9,
#          '월드': 77,
#          '챔피언십': 24,
#          '결승전': 15,
#          '오프닝': 8,
#          '무대': 25,
#          '직접': 102,
#          '애니메이션': 55,
#          '시즌': 303,
#          '엔딩': 69,
#          '라인': 79,
#          '프렌즈': 2,
#          '개봉': 10,
#          '박': 54,
#          '철': 37,
#          '임현준': 5,
#          '소연박': 1,
#          '유웅열': 2,
#          '게시': 23,
#          '하루': 52,
#          '유튜브': 60,
#          '회수': 17,
#          '다년': 128,
#          '후': 354,
#          '첫': 129,
#          '드라마': 81,
#          '제목': 27,
#          '뮤직': 9,
#          '팀': 426,
#          '연년': 1,
#          '커버': 11,
#          '회한': 1,
#          '정판': 1,
#          '이': 1265,
#          '중': 662,
#          '전체': 119,
#          '일부': 177,
#          '판': 1273,
#          '이전': 1312,
#          '역사': 1238,
#          '가기': 42,
#          '다른': 384,
#          '접기': 223,
#          '진주시': 10,
#          '시내버스': 13,
#          '통학': 5,
#          '노선': 45,
#          '동부': 16,
#          '순환': 11,
#          '경상대': 13,
#          '양호': 7,
#          '역': 83,
#          '이현동': 6,
#          '서부': 18,
#          '권역': 13,
#          '도심': 14,
#          '북부': 25,
#          '폐선': 5,
#          '문제점': 49,
#          '개편': 57,
#          '간격': 40,
#          '전면': 18,
#          '이후': 457,
#          '거': 195,
#          '평시': 4,
#          '정보': 122,
#          '특징': 42,
#          '평균': 43,
#          '승': 387,
#          '차량': 52,
#          '계': 48,
#          '철도역': 2,
#          '기점': 16,
#          '경상남도': 11,
#          '내동면': 2,
#          '율리': 2,
#          '남부': 24,
#          '차고': 10,
#          '종점': 6,
#          '덕산': 2,
#          '아파트': 34,
#          '행': 14,
#          '차': 112,
#          '차주': 1,
#          '공휴일': 39,
#          '평일': 28,
#          '막차막차': 1,
#          '배차': 19,
#          '출퇴근': 5,
#          '분': 133,
#          '운수': 3,
#          '사명': 7,
#          '진주': 18,
#          '시민버스': 5,
#          '대수': 11,
#          '일반': 224,
#          '그린빌': 5,
#          '경상': 4,
#          '국립': 9,
#          '대학교': 57,
#          '좌': 13,
#          '캠퍼스': 9,
#          '정문': 10,
#          '개': 393,
#          '오거리': 5,
#          '사대부고': 3,
#          '공과': 3,
#          '금호': 9,
#          '석류': 6,
#          '은빛': 4,
#          '한보': 1,
#          '남중': 1,
#          '학교': 189,
#          '일병': 2,
#          '포': 46,
#          '중앙시장': 3,
#          '갤러리아': 5,
#          '백화점': 10,
#          '여자': 120,
#          '고등학교': 240,
#          '진주보건대': 1,
#          '경진': 2,
#          '이현상': 4,
#          '아중': 1,
#          '고교': 26,
#          '운행': 43,
#          '왕복': 8,
#          '거리': 90,
#          '마산': 4,
#          '마이크로': 4,
#          '버스': 70,
#          '인수': 10,
#          '시작': 297,
#          '신설': 17,
#          '당시': 214,
#          '개양역': 1,
#          '인근': 16,
#          '출발': 5,
#          '년대': 196,
#          '초반': 87,
#          '대아고': 1,
#          '연장': 16,
#          '현재': 194,
#          '대가': 13,
#          '회': 206,
#          '약': 94,
#          '좌석버스': 3,
#          '번가': 2,
#          '폐지': 48,
#          '감차': 3,
#          '이동': 80,
#          '번호': 14,
#          '변경': 93,
#          '영차': 2,
#          '고지': 6,
#          '단순': 8,
#          '인': 135,
#          '대로': 30,
#          '횟수': 75,
#          '회주': 6,
#          '회로': 12,
#          '감회': 5,
#          '분주': 5,
#          '증차': 4,
#          '증회': 5,
#          '달리': 126,
#          '직선': 5,
#          '화가': 26,
#          '수요': 22,
#          '번은': 7,
#          '숯골': 1,
#          '셔틀': 5,
#          '점점': 39,
#          '길이': 23,
#          '편이': 124,
#          '시내': 7,
#          '구간': 46,
#          '여럿': 4,
#          '때문': 883,
#          '겹': 19,
#          '번의': 5,
#          '보조': 10,
#          '중이': 37,
#          '선형': 1,
#          '좌회전': 1,
#          '우회': 11,
#          '전': 572,
#          '평안': 1,
#          '광장': 19,
#          '전화국': 1,
#          '사거리': 15,
#          '오죽': 5,
#          '곳': 175,
#          '등교시간': 2,
#          '방향': 39,
#          '연암공대': 1,
#          '가지': 168,
#          '바로': 134,
#          '구내': 1,
#          '통해': 139,
#          '본선': 8,
#          '합류': 31,
#          '진양호': 13,
#          '계획': 72,
#          '문제': 333,
#          '무산': 7,
#          '에디슨': 4,
#          '화이': 2,
#          '버드': 9,
#          '탕': 2,
#          '오전': 5,
#          '시': 317,
#          '전후': 17,
#          '원': 44,
#          '출처': 30,
#          '교통': 12,
#          '안전': 10,
#          '공단': 17,
#          '국가': 57,
#          '대중교통': 5,
#          '별': 74,
#          '용인': 5,
#          '자료': 23,
#          '소수점': 2,
#          '자리': 78,
#          '반올림': 5,
#          '도일': 4,
#          '대비': 35,
#          '변동': 7,
#          '폭년년': 1,
#          '경유': 5,
#          '도로': 22,
#          '서장': 1,
#          '인창': 2,
#          '주유소': 4,
#          '창렬': 5,
#          '상봉': 10,
#          '현장': 29,
#          '민원': 9,
#          '실': 40,
#          '진주여고': 2,
#          '비봉': 4,
#          '로': 252,
#          '로서': 68,
#          '월화': 26,
#          '드림': 9,
#          '하이': 11,
#          '강력반': 3,
#          '동안미녀': 2,
#          '스파이': 7,
#          '명월': 4,
#          '포세이돈': 4,
#          '브레인': 2,
#          '드림하이': 2,
#          '사랑비': 2,
#          '해운대': 5,
#          '연인': 15,
#          '울랄라': 3,
#          '부부': 16,
#          '광고': 46,
#          '천재': 16,
#          '이태백': 3,
#          '직장': 10,
#          '상어': 28,
#          '굿': 8,
#          '닥터': 25,
#          '미래': 45,
#          '선택': 453,
#          '총리와': 3,
#          '나태': 2,
#          '양은': 5,
#          '빅맨': 2,
#          '트로트': 6,
#          '연애': 10,
#          '발견': 96,
#          '일도': 13,
#          '칸타빌레': 8,
#          '힐러': 18,
#          '블러드': 5,
#          '후아유': 2,
#          '너': 93,
#          '기억': 52,
#          '별난': 29,
#          '며느리': 2,
#          '고오': 2,
#          '마이': 17,
#          '비너스': 3,
#          '연': 25,
#          '방송': 209,
#          '시간': 285,
#          '월요일': 26,
#          '화요일': 8,
#          '기간': 50,
#          '부작': 9,
#          '채널': 39,
#          '제작사': 6,
#          '티모': 1,
#          '앤엠': 1,
#          '연출': 25,
#          '송현욱': 1,
#          '박진석': 1,
#          '극본': 3,
#          '황은경': 3,
#          '출연자': 8,
#          '김강우': 6,
#          '조여정': 12,
#          '정석원': 2,
#          '남규리': 1,
#          '링크': 30,
#          '공식': 73,
#          '홈페이지': 18,
#          '방영': 38,
#          '과정': 84,
#          '등장인물': 72,
#          '시청률': 31,
#          '추이': 4,
#          '이모저모': 1,
#          '조폭': 4,
#          '딸': 47,
#          '검사': 21,
#          '코믹': 10,
#          '로맨스': 6,
#          '그린': 26,
#          '티아라': 7,
#          '화영': 1,
#          '트위터': 54,
#          '가운데': 32,
#          '조연': 11,
#          '출연': 84,
#          '효민': 2,
#          '천': 6,
#          '남자': 83,
#          '은정': 2,
#          '다섯': 10,
#          '손가락': 14,
#          '시청자': 47,
#          '게시판': 16,
#          '연일': 4,
#          '난리': 6,
#          '상황': 250,
#          '먼저': 53,
#          '만큼': 76,
#          '향배': 1,
#          '갈릴': 2,
#          '도움': 61,
#          '만약': 52,
#          '역적': 2,
#          '영화': 59,
#          '캐스팅': 23,
#          '전망': 29,
#          '사실': 337,
#          '하차': 9,
#          '함은정': 2,
#          '전달': 8,
#          '대본': 2,
#          '분량': 13,
#          '첫방송': 1,
#          '마구': 10,
#          '주인공': 83,
#          '부산': 45,
#          '사투리': 9,
#          '표준어': 1,
#          '정체': 35,
#          '불명': 23,
#          '연기': 81,
#          '정도': 396,
#          '의견': 63,
#          '준비': 55,
#          '건': 183,
#          '년차': 4,
#          '배우': 116,
#          '감수': 9,
#          '비': 98,
#          '지역': 208,
#          '제작': 103,
#          '진도': 1,
#          '책임': 21,
#          '때': 824,
#          '장소': 30,
#          '배경': 42,
#          '케이블': 5,
#          '모': 33,
#          '대박': 7,
#          '친': 47,
#          '이유': 214,
#          '하나': 273,
#          '대다수': 38,
#          '경상도': 9,
#          '출신': 168,
#          '점': 246,
#          '감안': 26,
#          '아마': 25,
#          '하락': 10,
#          '원인': 35,
#          '어우동': 2,
#          '쇼': 63,
#          '미명': 1,
#          '하': 8,
#          '노이즈': 1,
#          '마케팅': 1,
#          '통한': 27,
#          '리기': 14,
#          '목적': 45,
#          '의혹': 21,
#          '불구': 41,
#          '두번째': 10,
#          '선전': 22,
#          '줄': 113,
#          '곤두박질': 1,
#          '뒤': 207,
#          '수치': 38,
#          '동안': 98,
#          '사': 37,
#          '올림픽': 46,
#          '중계로': 1,
#          '모두': 207,
#          '결방': 1,
#          '해당': 221,
#          '제한': 117,
#          '효과': 60,
#          '왕따': 2,
#          '사태': 41,
#          '이미지': 78,
#          '타격': 14,
#          '데': 152,
#          '다가': 41,
#          '걸': 196,
#          '경쟁력': 2,
#          '또': 124,
#          '개연': 2,
#          '스토리': 56,
#          '대한': 354,
#          '몰이': 26,
#          '연기력': 14,
#          '복합': 5,
#          '작용': 14,
#          '평이': 9,
#          '계속': 96,
#          '바닥': 28,
#          '희망': 9,
#          '요소': 42,
#          '스타': 47,
#          '경우': 779,
#          '생각': 239,
#          '상술': 16,
#          '메': 173,
#          '결과': 565,
#          '폭': 38,
#          '매화': 1,
#          '심지어': 82,
#          '엉덩이': 6,
#          '비판': 108,
#          '저런': 10,
#          '무리수': 1,
#          '퀄리티': 3,
#          '못': 203,
#          '화로': 5,
#          '종영': 5,
#          '시간대': 14,
#          '꼴': 22,
#          '이상': 293,
#          '후속작': 10,
#          '기여': 9,
#          '선방': 4,
#          '편': 150,
#          '소라': 7,
#          '자갈치시장': 1,
#          '삼촌': 10,
#          '수산': 3,
#          '실질': 15,
#          '경영': 5,
#          '아버지': 107,
#          '결혼': 36,
#          '재촉': 2,
#          '업체': 13,
#          '소개': 35,
#          '공무원': 24,
#          '맞선': 2,
#          '보기': 49,
#          '이태성': 1,
#          '여정': 4,
#          '마약운반책': 2,
#          '착각': 11,
#          '진짜': 73,
#          '검거': 5,
#          '도중': 43,
#          '머리': 101,
#          '바다': 17,
#          '가까스로': 1,
#          '산호': 2,
#          '강우': 3,
#          '기억상실증': 1,
#          '최준혁': 4,
#          '호텔': 14,
#          '부사': 1,
#          '겸': 46,
#          '변호사': 9,
#          '활': 11,
#          '고등어': 1,
#          '페스티벌': 4,
#          '만난': 11,
#          '신경': 30,
#          '나남': 1,
#          '규리': 2,
#          '약혼녀': 1,
#          '법무부': 6,
#          '장관': 41,
#          '디자이너': 41,
#          '서브': 37,
#          '주연': 12,
#          '갈수록': 13,
#          '존재': 136,
#          '감': 76,
#          '거의': 139,
#          '하자': 35,
#          '특별출연': 4,
#          '전환': 29,
#          '진': 98,
#          '분명': 18,
#          '중반': 33,
#          '러브': 22,
#          '생': 61,
#          '놈': 76,
#          '얘기': 36,
#          '산산': 1,
#          '작가': 75,
#          '전작': 30,
#          '뉴하트': 1,
#          '이지훈': 2,
#          '대폭': 8,
#          '삭제': 27,
#          '후반': 49,
#          '부': 112,
#          '주지': 19,
#          '집필': 3,
#          '디데이': 1,
#          '하석진': 1,
#          '작품': 94,
#          '특정': 38,
#          '주의': 234,
#          '언제': 15,
#          '황주희': 1,
#          '강민경': 1,
#          '동창': 4,
#          '사이': 127,
#          '그다지': 22,
#          '대학': 50,
#          '비서': 10,
#          '준혁': 1,
#          '마음': 64,
#          '위해': 255,
#          '월급': 3,
#          '대부분': 129,
#          '미용': 1,
#          '투자': 18,
#          '관순': 2,
#          '정말': 77,
#          '알바': 4,
#          '번돈': 1,
#          '전부': 69,
#          '명품': 12,
#          '부터': 39,
#          '등장': 424,
#          '실수': 27,
#          '값': 15,
#          '양주': 1,
#          '깨': 8,
#          '언니': 20,
#          '달라': 39,
#          '장본인': 3,
#          '트럭': 13,
#          '감금': 2,
#          '이동백': 1,
#          '건일': 1,
#          '짝사랑': 5,
#          '검정고시': 194,
#          '부영': 2,
#          '박상면': 1,
#          '소녀': 29,
#          '감성': 2,
#          '소유자': 8,
#          '중식': 1,
#          '임하룡': 1,
#          '전직': 27,
#          '두목': 4,
#          '인자': 6,
#          '배반': 2,
#          '실각': 1,
#          '심장': 12,
#          '보통': 62,
#          '이순신': 8,
#          '이재용': 2,
#          '여수': 1,
#          '세조': 4,
#          '최상훈': 2,
#          '로펌': 1,
#          '대표': 136,
#          '태': 9,
#          '입양': 3,
#          '다육': 1,
#          '김혜은': 1,
#          '사장': 31,
#          '부인': 16,
#          '강민구': 1,
#          '김태현': 1,
#          '속': 110,
#          '접근': 23,
#          '세금': 8,
#          '거지': 14,
#          '돈': 125,
#          '글자': 34,
#          '의미': 97,
#          '제공': 21,
#          '닐슨': 1,
#          '코리아': 11,
#          '회차': 11,
#          '방영일': 5,
#          '전국': 59,
#          '서울': 137,
#          '수도권': 20,
#          '발연기': 7,
#          '본인': 227,
#          '주장': 92,
#          '포화': 7,
#          '나': 142,
#          '부각': 5,
#          '인터뷰': 34,
#          '사람': 428,
#          '분위기': 43,
#          '나름': 35,
#          '인간중독': 1,
#          '각종': 50,
#          '영화제': 2,
#          '여우': 5,
#          '연상': 32,
#          '노미네이트': 1,
#          '시상': 2,
#          '쾌거': 2,
#          '꽤': 95,
#          '벗방': 4,
#          '가슴': 15,
#          '밀착': 3,
#          '씬': 5,
#          '비키니': 7,
#          '사워씬': 1,
#          '샤워': 2,
#          '노출': 20,
#          '기존': 75,
#          '젠': 71,
#          '훌렁': 1,
#          '시도': 59,
#          '오히려': 116,
#          '비난': 30,
#          '여론': 25,
#          '매': 10,
#          '지경': 11,
#          '기도': 110,
#          '대역': 3,
#          '실패': 28,
#          '흐름': 7,
#          '스르': 2,
#          '역시': 151,
#          '성적': 55,
#          '다만': 171,
#          '한자리': 2,
#          '전형': 34,
#          '마지막': 94,
#          '골든타임': 1,
#          '대규모': 7,
#          '자금': 5,
#          '경쟁': 25,
#          '작': 35,
#          '신의': 5,
#          '제': 95,
#          '차지': 48,
#          '차기작': 1,
#          '라라': 9,
#          '사격': 23,
#          '셈': 26,
#          '미니시리즈': 2,
#          '기획': 21,
#          '달': 60,
#          '내내': 16,
#          '등등': 28,
#          '커녕': 7,
#          '달성': 42,
#          '일찍': 14,
#          '몫': 7,
#          '볼': 182,
#          '부산광역시': 13,
#          '해운대구': 2,
#          '청사포': 1,
#          '촬영': 36,
#          '명': 320,
#          '김광수': 1,
#          '회사': 24,
#          '소속': 75,
#          '가수': 110,
#          '네이버': 30,
#          '웹툰': 40,
#          '연재': 57,
#          '목금': 19,
#          '토': 178,
#          '요괴': 17,
#          '장르': 14,
#          '액션': 1,
#          '판타지': 29,
#          '가글': 1,
#          '강두': 2,
#          '그림': 62,
#          '장부': 2,
#          '규': 16,
#          '처': 56,
#          '종료': 26,
#          '주기': 20,
#          '이용': 163,
#          '등급': 61,
#          '줄거리': 15,
#          '글': 99,
#          '담당': 53,
#          '강시': 11,
#          '퇴치': 14,
#          '소년만화': 1,
#          '왕도': 1,
#          '소년': 22,
#          '만화': 55,
#          '다크': 12,
#          '가미': 12,
#          '동양': 10,
#          '주로': 69,
#          '히로인': 8,
#          '행적': 23,
#          '호불호': 6,
#          '아침': 14,
#          '필립': 36,
#          '난': 48,
#          '인간': 79,
#          '현황': 14,
#          '잠정': 2,
#          '완결': 11,
#          '상태': 188,
#          '나중': 36,
#          '기회': 28,
#          '대전': 54,
#          '대학생': 8,
#          '이마': 2,
#          '안': 351,
#          '날': 129,
#          '적': 266,
#          '귀신': 8,
#          '능력': 221,
#          '하필': 23,
#          '이면': 33,
#          '악한': 2,
#          '바람': 62,
#          '뻔': 7,
#          '그': 901,
#          '곧바로': 15,
#          '목': 100,
#          '사망': 61,
#          '여파': 9,
#          '밥': 32,
#          '이외': 30,
#          '음식': 37,
#          '강': 148,
#          '호수': 20,
#          '몸': 91,
#          '제대로': 70,
#          '움직': 11,
#          '추가': 142,
#          '정신': 46,
#          '누가': 20,
#          '물': 84,
#          '그대로': 199,
#          '다행': 19,
#          '특이': 9,
#          '체질': 16,
#          '흉': 4,
#          '약점': 35,
#          '통': 57,
#          '햇빛': 2,
#          '링': 24,
#          '빙과': 2,
#          '팔이': 9,
#          '의수': 2,
#          '착용': 22,
#          '장악': 14,
#          '팔': 152,
#          '재생': 15,
#          '다시': 217,
#          '주도': 12,
#          '덤': 38,
#          '머리카락': 10,
#          '백발': 4,
#          '원래': 110,
#          '머리색': 2,
#          '프롤로그': 5,
#          '혼백': 8,
#          '파라': 20,
#          '조직': 32,
#          '위기': 54,
#          '구': 104,
#          '갑자기': 32,
#          '부활': 47,
#          '파': 38,
#          ...})

# %%
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)
# Out:
# Counter({'승패': 1690, '문서': 1421, '문단': 1411, '이전': 1312, '역사': 1238, '이름': 996, '트랙': 939, '때문': 883, '경우': 779, '아이템': 710, '경기': 586, '결과': 565, '선수': 564, '모델': 476, '이후': 457, '선택': 453, '사용': 453, '사람': 428, '스피드': 428, '등장': 424, '사항': 424, '합의': 423, '토론': 421, '공격': 417, '정도': 396, '부분': 387, '헨리': 387, '다른': 384, '자신': 368, '한국': 357, '대한': 354, '일본': 351, '사실': 337, '문제': 333, '레킹볼': 321, '시즌': 303, '내용': 300, '시작': 297, '이상': 293, '시간': 285, '스킬': 275, '모습': 274, '하나': 273, '게임': 272, '사건': 270, '피해': 263, '관련': 260, '위해': 255, '또한': 253, '캐릭터': 251, '상황': 250, '고등학교': 240, '페미니즘': 240, '생각': 239, '주의': 234, '매우': 233, '여성': 228, '건빵': 228, '본인': 227, '일반': 224, '접기': 223, '실제': 223, '인천': 222, '해당': 221, '능력': 221, '다시': 217, '당시': 214, '이유': 214,
최대': 85, '차이': 85, '과정': 84, '출연': 84, '조선': 84, '이자': 84, '문화': 84, '국내': 84, '초인': 84, '남자': 83, '주인공': 83, '화면': 83, '관통': 83, '종류': 82, '심지어': 82, '확인': 82, '설명': 82, '업데이트': 82, '제로': 82, '대구': 82, '드라마': 81, '연기': 81, '단체': 81, '이드': 81, '이동': 80, '라이온즈': 80, '패션': 80, '방식': 80, '한자': 80, '최고': 79, '라인': 79, '인간': 79, '블랙': 79, '자리': 78, '이미지': 78, '강화': 78, '여러': 78, '개발': 78, '루트': 78, '바디': 78, '구단': 78, '카트': 78, '월드': 77, '정말': 77, '인기': 77, '전선': 77, '루리웹': 77, '적용': 77, '우주': 77, '의성': 77, '레지널드': 77, '만큼': 76, '중앙': 76, '조금': 76, '실점': 76, '색각': 76, '국회의원': 76, '이닝': 76, '횟수': 75, '작가': 75, '기존': 75, '소속': 75, '설정': 75, '사진': 75, '윈스턴': 75, '대회': 75, '정당': 74, '운동': 74, '비롯': 74, '조합': 74, '영웅': 74, '감소': 74, '에리': 74, '비밀': 74, '공식': 73, '진짜': 73, '개방': 73, '제대': 73, '드립': 73, '반응': 73, '갈고리': 73, '카이': 73, '구분': 73, '브레이크': 73, '아야': 73, '에이스': 73, '목록': 72, '계획': 72, '등장인물': 72, '합격': 72, '서로': 72, '표기': 72, '속도': 72, '단계': 7 ...

# %% [markdown]
# ### 2. 불용어 제거하기

# %%
# 한국어 약식 불용어사진 예시 파일 (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "./data/korean_stopwords.txt"

with open(korean_stopwords_path, encoding = 'utf8') as f:
    stopwords = f.readlines()

stopwords = [x.strip() for x in stopwords]
print(stopwords[:10])
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %%
namu_wiki_stopwords = ['상위', '문서', '내용', '누설', '아래', '해당',
                       '설명', '표기', '추가', '모든', '사용', '매우', 
                       '가장', '줄거리', '요소', '상황', '편집', '틀',
                       '경우', '때문', '모습', '정도', '이후', '사실',
                       '생각', '인물', '이름', '년월']

for stopword in namu_wiki_stopwords:
    stopwords.append(stopword)

# %%
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})
print(remove_char_counter)
# Out:
# Counter({'승패': 1690, '문단': 1411, '이전': 1312, '역사': 1238, '트랙': 939, '아이템': 710, '경기': 586, '결과': 565, '선수': 564, '모델': 476, '선택': 453, '사람': 428, '스피드': 428, '등장': 424, '사항': 424, '합의': 423, '토론': 421, '공격': 417, '부분': 387, '헨리': 387, '한국': 357, '대한': 354, '일본': 351, '문제': 333, '레킹볼': 321, '시즌': 303, '시작': 297, '스킬': 275, '게임': 272, '사건': 270, '피해': 263, '관련': 260, '위해': 255, '캐릭터': 251, '고등학교': 240, '페미니즘': 240, '주의': 234, '여성': 228, '건빵': 228, '본인': 227, '일반': 224, '접기': 223, '실제': 223, '인천': 222, '능력': 221, '다시': 217, '당시': 214, '이유': 214, '패승': 214, '방송': 209, '지역': 208, '그대로': 199, '소피아': 198, '년대': 196, '현재': 194, '검정고시': 194, '증가': 191, '학교': 189, '상태': 188, '자체': 188, '대한민국': 186, '참고': 186,
�': 79, '자리': 78, '이미지': 78, '강화': 78, '여러': 78, '개발': 78, '루트': 78, '바디': 78, '구단': 78, '카트': 78, '월드': 77, '정말': 77, '인기': 77, '전선': 77, '루리웹': 77, '적용': 77, '우주': 77, '의성': 77, '레지널드': 77, '만큼': 76, '중앙': 76, '실점': 76, '색각': 76, '국회의원': 76, '이닝': 76, '횟수': 75, '작가': 75, '기존': 75, '소속': 75, '설정': 75, '사진': 75, '윈스턴': 75, '대회': 75, '정당': 74, '운동': 74, '비롯': 74, '조합': 74, '영웅': 74, '감소': 74, '에리': 74, '비밀': 74, '공식': 73, '진짜': 73, '개방': 73, '제대': 73, '드립': 73, '반응': 73, '갈고리': 73, '카이': 73, '구분': 73, '브레이크': 73, '에이스': 73, '목록': 72, '계획': 72, '등장인물': 72, '합격': 72, '서로': 72, '속도': 72, '단계': 72, '진출': 71, '마스터': 71, '실험': 71, '종합': 71, '전혀': 71, '대상': 71, '녹색': 71, '버스': 70, '제대로': 70, '발표': 70, '디시': 70, '이제': 70, '엔딩': 69, '주로': 69, '결정전': 69, '서머': 69, '승부': 69, '탈출': 69, '아이돌': 69, '응시': 69, '로서': 68, '자책': 68, '더욱': 67, '동시': 67, '학력': 67, '졸업': 67, '역할': 67, '수가': 67, '계정': 67, '포트': 67, '탱커': 67, '궁극': 67, '마을': 67, '파일럿': 67, '해외': 66, '발매': 66, '확정': 66, '특성': 66, '행동': 66, '예천군': 66, '정치인': 66, '참여': 65, '운영': 65, '주변': 65 ...

# %% [markdown]
# ### 3. 시각화 : 워드 클라우드 시각화

# %% [markdown]
# ### [ 나무위키 키워드 시각화 ]

# %% [markdown]
# ##### 한글 폰트 다운로드받기
# - http://hangeul.naver.com/webfont/NanumGothic/NanumGothic.ttf

# %% [markdown]
# - 제목 키워드

# %%
# !pip install pytagcloud pygame simplejson
# Out:
# Requirement already satisfied: pytagcloud in c:\users\user\anaconda3\lib\site-packages (0.3.5)
# Requirement already satisfied: pygame in c:\users\user\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: simplejson in c:\users\user\anaconda3\lib\site-packages (3.17.2)

# %%
import random
import pytagcloud
import webbrowser

# 가장 출현 빈도수가 높은 40개의 단어를 선정합니다.
ranked_tags = remove_char_counter.most_common(40)

# pytagcloud로 출력할 40개의 단어를 입력합니다. 단어 출력의 최대 크기는 80으로 제한합니다.
taglist = pytagcloud.make_tags(ranked_tags, maxsize = 80)

# pytagcloud 이미지를 생성합니다. 폰트는 나눔 고딕을 사용합니다.
pytagcloud.create_tag_image(taglist, './chapter2/wordcloud.jpg', size = (900, 600),
                            fontname = 'NanumGothic', rectangular=False)

# %%
from IPython.display import Image
Image(filename = './chapter2/wordcloud.jpg')

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(title_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, './chapter2/title_wordcloud.jpg', size = (900, 600),
                            fontname = 'NanumGothic', rectangular = False)

Image(filename = './chapter2/title_wordcloud.jpg')

# %% [markdown]
# - 카테고리 키워드

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(category_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, './chapter2/category_wordcloud.jpg', size = (900, 600),
                            fontname = 'NanumGothic', rectangular = False)

Image(filename = './chapter2/category_wordcloud.jpg')
